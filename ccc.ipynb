# %% [markdown]
# <a href="https://colab.research.google.com/github/cesar-jaz1/ESCOM/blob/main/ccc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

def factorizacion_LU(A):
    A = A.astype(float)
    n = len(A)

    L = np.eye(n)        # L arranca con 1s en la diagonal
    U = A.copy()         # U comienza igual que A

    # Eliminación gaussiana
    for k in range(n-1):
        for i in range(k+1, n):
            # factor para eliminar A[i][k]
            L[i, k] = U[i, k] / U[k, k]
            U[i, :] = U[i, :] - L[i,k] * U[k,:]

    return L, U

# Ejemplo de uso
A = np.array([[4, 3], [6, 3]], float)
L, U = factorizacion_LU(A)
print(L)
print(U)
